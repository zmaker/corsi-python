# %% [markdown]
# ## Esercizio Pandas
#
# Scaricare un file con dati da kaggle es: dati delle case di Amsterdam
#
# https://www.kaggle.com/datasets/thomasnibb/amsterdam-house-price-prediction?select=HousingPrices-Amsterdam-August-2021.csv
#
# * verificare che i dati siano puliti e nel caso, ripulirli
# * calcolare il prezzo medio di una casa ad Amsterdam
# * calcolare la sup media di una casa ad Amsterdam
# * tracciare un grafico a barre con la distribuzione del prezzo in funziona della superficie
# * tracciare un grafico scatter con distribuzione di prezzi e superficie
# * si possono mettere delle info su una mappa? es. google maps? (libreria folium di python)
