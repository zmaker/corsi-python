# %% [markdown]
# ## Ex2 - Pandas
#
# tre file con:
# * clienti
# * prodotti
# * transazioni
#
# Verificare i file.
#
# combinare i dati per ricavare:
# * quale cliente ha speso di più
# * il prodotto più venduto
# * una classifica dei 10 prodotti più venduti
