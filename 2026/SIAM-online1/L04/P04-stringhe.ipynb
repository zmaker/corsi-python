# %% [markdown]
# ### Stringhe

# %%
a = "hello"
b = "world"

# %% [markdown]
# Concatenazione

# %%
c = a + " " + b
print(c)
# Out:
# hello world

# %%
n = 12
d = "n vale " + str(n)
print(d)
# Out:
# n vale 12

# %%
txt = "ABCDEFGHI"
print(txt[1])
# Out:
# B

# %%
for ch in txt:
    print(ch)
# Out:
# A
# B
# C
# D
# E
# F
# G
# H
# I

# %%
testo = "era una notte buia e tempestosa..."
print(testo[4:9])
print(testo[10:])
print(testo[:5])
print(testo[-5:])
# Out:
# una n
# tte buia e tempestosa...
# era u
# sa...

# %%
print(testo[4:9:2])
# Out:
# uan

# %%
if "notte" in testo:
    print("trovato")
# Out:
# trovato

# %%
riga = "    mario     "
riga = riga.strip()
print(riga)
# Out:
# mario

# %%
print(riga.upper())
print(riga.lower())
print(riga.title())
# Out:
# MARIO
# mario
# Mario

# %%
dati = "12,     34, 45   , 56,   67 ,    78,   67"
lista = dati.split(",")
print(lista)
# Out:
# ['12', '     34', ' 45   ', ' 56', '   67 ', '    78', '   67']

# %%
for n in lista:
    print(int(n.strip()))
# Out:
# 12
# 34
# 45
# 56
# 67
# 78
# 67
